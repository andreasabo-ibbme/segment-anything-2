# %%
import torch
import glob, os

from icecream import ic
import mask_extraction_utils
import extract_masks
import matplotlib

matplotlib.rcParams['savefig.dpi'] = 300
matplotlib.rcParams["figure.dpi"] = 100

# %%
INPUT_IMAGE_FOLDER = r"/home/saboa/mnt/n_drive/AMBIENT/Andrea_S/EDS/DLC_working_dir/dlc_projects_participants/EDS001_EDS100__FifthFinger-liam-2023-07-04_SAM2/labeled-data/"
OUTPUT_FOLDER = r"/home/saboa/mnt/n_drive/AMBIENT/Andrea_S/EDS/DLC_working_dir/dlc_projects_participants_SAM2/EDS001_EDS100__FifthFinger-liam-2023-07-04_SAM2/labeled-data/"
FOLDER_PREFIX = "andrea_new-"

# %%
extract_masks.prerun_settings()

# %%
def list_all_folders(INPUT_IMAGE_FOLDER):
    all_folders = glob.glob(os.path.join(INPUT_IMAGE_FOLDER, f"{FOLDER_PREFIX}*"))
    return all_folders

# %%
folders_to_process = list_all_folders(INPUT_IMAGE_FOLDER)

# %%
mask_extraction_utils.process_all_folders(folders_to_process, OUTPUT_FOLDER, FOLDER_PREFIX)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 mask_extraction_utils.process_all_folders(folders_to_process, OUTPUT_FOLDER, FOLDER_PREFIX)
#
# File ~/code/segment-anything-2/notebooks/mask_extraction_utils.py:272, in process_all_folders(folders, output_folder, folder_prefix)
#     269 cur_output_folder = cur_output_folder.replace(folder_prefix, "")
#     271 os.makedirs(cur_output_folder, exist_ok=True)
# --> 272 process_folder(folder, label_csv, predictor, cur_output_folder)
#
# File ~/code/segment-anything-2/notebooks/mask_extraction_utils.py:223, in process_folder(folder, label_csv, predictor, output_folder)
#     212 if not mask_pixels:
#     213     show_masks_combined(
#     214         image,
#     215         masks,
#    (...)
#     220         image_name=output_image,
#     221     )
# --> 223     mask_id = int(input("Which mask to select? 0-indexed\n"))
#     224     plt.close()
#     225     mask_pixels = masks[mask_id].sum()
#
# ValueError: invalid literal for int() with base 10: ''
